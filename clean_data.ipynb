# %%
import pandas as pd

# %%
data = pd.read_excel('./data_xls/catalog.xls')

# %%
data
# Out:
#                          AUTHOR  \
# 0              AACHEN, Hans von
# 1              AACHEN, Hans von
# 2              AACHEN, Hans von
# 3              AACHEN, Hans von
# 4              AACHEN, Hans von
# 5        AAGAARD, Carl Frederik
# 6        AAGAARD, Carl Frederik
# 7            ABADIA, Juan de la
# 8            ABAQUESNE, Masséot
# 9            ABAQUESNE, Masséot
# 10           ABAQUESNE, Masséot
# 11           ABAQUESNE, Masséot
# 12        ABBATE, Niccolò dell'
# 13        ABBATE, Niccolò dell'
# 14        ABBATE, Niccolò dell'
# 15        ABBATE, Niccolò dell'
# 16        ABBATE, Niccolò dell'
# 17        ABBATE, Niccolò dell'
# 18             ABBATI, Giuseppe
# 19             ABBATI, Giuseppe
# 20             ABBATI, Giuseppe
# 21             ABBATI, Giuseppe
# 22       ABBATINI, Guido Ubaldo
# 23           ABEELE, Pieter van
# 24           ABEELE, Pieter van
# 25           ABEELE, Pieter van
# 26          ABILDGAARD, Nicolai
# 27          ABILDGAARD, Nicolai
# ...

# %%
data['TIMEFRAME_START'], data['TIMEFRAME_END'] = data['TIMEFRAME'].str.split('-').str

# %%
del data['TIMEFRAME']

# %%
data['AUTHOR_BORN_DATE'], data['AUTHOR_BORN_PLACE'], data['AUTHOR_DEATH_DATE'], data['AUTHOR_DEATH_PLACE'] = [data['BORN-DIED'].str, data['BORN-DIED'].str, data['BORN-DIED'].str, data['BORN-DIED'].str].str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-d2d086cdfe10> in <module>()
# ----> 1 data['AUTHOR_BORN_DATE'], data['AUTHOR_BORN_PLACE'], data['AUTHOR_DEATH_DATE'], data['AUTHOR_DEATH_PLACE'] = [data['BORN-DIED'].str, data['BORN-DIED'].str, data['BORN-DIED'].str, data['BORN-DIED'].str].str
#
# AttributeError: 'list' object has no attribute 'str'

# %%
data['AUTHOR_BORN_DATE'] = data['BORN-DIED'].str
